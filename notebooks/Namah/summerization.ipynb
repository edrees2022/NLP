# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
qa =pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# ...

# %%
ctx="my name is Namah,iam studying data"
que="what is Namah studying"
qa(context=ctx, question=que)
# Out:
# {'score': 0.7264324426651001, 'start': 30, 'end': 34, 'answer': 'data'}

# %%
ctx="the South African-born entrepreneur widely known as the founder of SpaceX and Tesla, is renowned for his advances in electric vehicles and space travel"
que="who is Elon musk?"
qa(context=ctx, question=que)
# Out:
# {'score': 0.30114084482192993,
#  'start': 0,
#  'end': 35,
#  'answer': 'the South African-born entrepreneur'}

# %%
ctx="Elon Reeve Musk was born on June 28, 1971"
que="when was Elon musk born?"
qa(context=ctx, question=que)
# Out:
# {'score': 0.9573829174041748,
#  'start': 28,
#  'end': 41,
#  'answer': 'June 28, 1971'}

# %%
# prompt:  code for text sumerization with pipline

from transformers import pipeline
# !pip install transformers

summarizer = pipeline("summarization")

text = """
Elon Musk is a South African-born American entrepreneur and businessman who founded X.com in 1999 (which later became PayPal), SpaceX in 2002 and Tesla Motors in 2003. Musk became a multimillionaire in his late 20s when he sold his start-up company, Zip2, to a division of Compaq Computers.

Musk made headlines in May 2012, when SpaceX launched a rocket that would send the first commercial vehicle to the International Space Station. In September 2016, he unveiled plans to send humans to Mars by 2026.

In 2018, Musk was in the news for taking Tesla private. The deal, however, fell through. He was also criticized for his erratic behavior on Twitter, including smoking marijuana on a live webcast.

In 2022, Musk became the richest person in the world, surpassing Jeff Bezos. He is also the CEO of Twitter, which he acquired in a $44 billion deal.
"""

summary = summarizer(text)

print(summary)
# Out:
# ...
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'summary_text': ' Elon Musk is a South African-born American entrepreneur and businessman . He founded X.com in 1999, PayPal in 2002 and Tesla Motors in 2003 . He became a multimillionaire in his late 20s when he sold his start-up company, Zip2, to Compaq Computers .'}]

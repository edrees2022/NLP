# %%
from transformers import pipeline,set_seed

# %%
import textwrap
import numpy as np
import matplotlib.pyplot as plt

from pprint import pprint

# %%
gen = pipeline('text-generation',model="elgeish/gpt2-medium-arabic-poetry")

# %%
def wrap(x):
    return textwrap.fill(x, replace_whitespace= False, fix_sentence_endings= True)
    #لتنسيق النصوص والفقرات وتنظيمها  بطريقة معينة

# %%
t=(" الحيوانات البرية")

# %%
gen(t)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': ' الحيوانات البرية التي لم تعد قادرة علي تغير الوان البشر والحيوانات الاليفة والطيور التي لا تستطيع ان تغير اشكال البشر والحيوانات المفترسة وحيواناتها الاكثر رافة بحياتها وطيورها الضاجة بالفراءض والاسماك الصغيرة والحيوانات المفترسه والحيوانات المنبوحة والحيوانات المفتر'}]

# %%
text1 = "فلسطين "
gen(text1)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': 'فلسطين مءذنة في كل شرق ومغرب وفي كل شبر من ثري القدس مسجد وفي كل بيت من بيوت بني الاسلام قاءم وفي كل ارض من ربوع فلسطين مغرد وفي كل دار من معاهد العلم معلمة وفي كل ناد من'}]
